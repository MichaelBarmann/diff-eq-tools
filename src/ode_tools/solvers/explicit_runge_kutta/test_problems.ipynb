# %% [markdown]
# ### `test_problems.ipynb`
# *Created*: Sept 18, 2026 <br/>
# *About*: Some ODE problems for testing the Explicit Runge-Kutta solvers.

# %%
using UnPack

struct ODETestProblem{F, U, P, S}
    f::F
    u0::U
    tspan::Tuple{Float64, Float64}
    p::P
    exact_solution::S
end 

function ODETestProblem(f::F, u0::U, tspan::NTuple{2,<:Real}, p::P = nothing; exact_solution::S = nothing) where {F,U,P,S}
    tspan = Float64.(tspan)
    return ODETestProblem(f, u0, tspan, p, exact_solution)
end
# Out:
# ODETestProblem

# %%
#Exponential function
exponential_rhs(u,p,t) = u          #RHS
exponential_exact(t,p) = exp(t)     #Exact solution

#Sine function
sinusoid_rhs(u,p,t) = cos(t)      #RHS
sinusoid_exact(t,p) = sin(t)      #Exact solution

#Damped oscillator
function damped_oscillator_rhs(u,p,t)
    y, z = u 
    dy = z 
    dz = -y - z/8
    
    du = [dy, dz]
    return du
end 

function damped_oscillator_exact(t,p)
    A = 2.0
    B = 2/sqrt(255)
    ω = sqrt(255) / 16
    return exp(-t/16) * (A*cos(ω*t) + B*sin(ω*t))
end 

function lotka_volterra_rhs(u,p,t)
    @unpack α, β, δ, γ = p
    x, y = u

    dx = α*x - β*x*y
    dy = δ*x*y - γ*y
    
    du = [dx, dy]
    return du
end

function lorenz_rhs(u,p,t)
    @unpack σ, ρ, β = p
    x, y, z = u 
    du = [σ*(y - x), x*(ρ - z) - y, x*y - β*z]
    return du 
end
# Out:
# lorenz_rhs (generic function with 1 method)

# %%
#Define some test problems
exp_growth = ODETestProblem(exponential_rhs, 1.0, (0.0, 10.0));
sinusoid = ODETestProblem(sinusoid_rhs, 0.0, (0.0, 10.0));
damped_oscillator = ODETestProblem(damped_oscillator_rhs, [2.0, 0.0], (0.0, 10.0));
lotka_volterra = ODETestProblem(lotka_volterra_rhs, [1.0, 1.0], (0.0, 10.0), (α = 1.5, β = 1.0, δ = 1.0, γ = 3.0));
lorenz_system = ODETestProblem(lorenz_rhs, [1.0, 1.0, 1.0], (0.0, 10.0), (σ = 10.0, ρ = 28.0, β = 8/3));
