# %% [markdown]
# ### `runge_kutta.ipynb`
# *Created: Sept 21, 2026* <br/>
# This notebook exists to define the abstract type `ExplicitRungeKuttaMethod`. The function `compare_solution` in `ode_library.ipynb` requires that the custom algorithm passed is an ExplicitRungeKuttaMethod. <br/>
#
# *Note: `OrdinaryDiffEq.jl` defines the type `ExplicitRK`, so we can't reuse that name.

# %%
abstract type ExplicitRungeKuttaMethod end
