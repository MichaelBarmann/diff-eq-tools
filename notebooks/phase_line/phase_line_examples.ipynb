# %%
f(x) = x^2*(x-1)*(x-2)^2*(x-3) 

phase_line(f, a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-10, npoints = 200, xmin = -2.0, xmax = 4.0, ymin = -2.0, ymax = 2.0,
            title = "Phase Line", xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
phase_line(x -> -x^3, a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-10, npoints = 200, xmin = -2.0, xmax = 4.0, ymin = -2.0, ymax = 2.0,
            title = "Phase Line", xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#S24 Applied Math Qual: Problem 1 
f(x, μ) = μ + 2*x^2 - x^4 
phase_line(f, a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-12, npoints = 200, ymin = -2.0, ymax = 2.0, xmin = -1.0, xmax = 4.0,
            title = "Phase Line", xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#S25 Applied Math Qual: Problem 2 
g(x, λ) = λ - 3*x^4 + 8*x^3 + 6*x^2 - 24*x 
F(x, λ) = (x-1.0)*g(x, λ)

xmin = -3.0
xmax = 3.0 

λ_vals = collect(LinRange(-25.0, 25.0, 801))
λ_crit = [-19.0, 8.0, 13.0]
append!(λ_vals, λ_crit)

bd_g = bifurcation_diagram(g; λ_vals = λ_vals, xmin = xmin, xmax = xmax, title = "", λ_crit = λ_crit)
bd_f = bifurcation_diagram(F; λ_vals = λ_vals, xmin = xmin, xmax = xmax, title = "", λ_crit = λ_crit);

# %%
#S25 Applied Math Qual: Problem 2 
g(x, λ) = λ - 3*x^4 + 8*x^3 + 6*x^2 - 24*x 
#F(x, λ) = (x-1.0)*g(x, λ)

xmin = -3.0
xmax = 3.0 

λ_vals = collect(LinRange(-25.0, 25.0, 801))
λ_crit = [-19.0, 8.0, 13.0]
append!(λ_vals, λ_crit)

bd_g = bifurcation_diagram(g; λ_vals = λ_vals, xmin = xmin, xmax = xmax, title = title, λ_crit = λ_crit)


#filename = "S24_Q1_phase_portrait_mu=$μ.png"
#    save(filename, pp)

# %%
λ = λ_vals[1]
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-12, npoints = 200, 
           xmin = -2.0, xmax = 2.0, ymin = -30.0, ymax = 30.0, title = L"λ = %$(round(Int, λ))",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
λ = λ_vals[2]
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-12, npoints = 200, 
           xmin = -2.0, xmax = 2.0, ymin = -30.0, ymax = 30.0, title = L"λ = %$(round(Int, λ))",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
λ = -17.0
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-12, npoints = 200, 
           xmin = -2.0, xmax = 2.0, ymin = -30.0, ymax = 30.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
λ = λ_vals[3]
λ = 6.5
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-20, Δx = 1e-8, npoints = 200, 
           xmin = -3.0, xmax = 3.0, ymin = -30.0, ymax = 30.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
λ = λ_vals[4]
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-5, f_tol = 1e-20, npoints = 200, 
           xmin = -3.0, xmax = 3.0, ymin = -30.0, ymax = 30.0, title = L"λ = %$(round(Int, λ))",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#λ = λ_vals[5]
λ = 8.5
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-8, f_tol = 1e-20, npoints = 200, 
           xmin = -3.0, xmax = 3.0, ymin = -5.0, ymax = 5.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
λ = λ_vals[6]
λ = 11.0
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-8, f_tol = 1e-20, npoints = 200, 
           xmin = -3.0, xmax = 4.0, ymin = -5.0, ymax = 5.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#λ = λ_vals[6]
λ = 13.0
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-8, f_tol = 1e-20, npoints = 200, 
           xmin = -3.0, xmax = 4.0, ymin = -5.0, ymax = 7.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#λ = λ_vals[6]
λ = 14.0
fig = phase_line(x -> F(x,λ), a = -3.0, b = 3.0, df_tol = 1e-8, f_tol = 1e-20, npoints = 200, 
           xmin = -3.0, xmax = 4.0, ymin = -5.0, ymax = 7.0, title = L"λ = %$λ",
           xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
#GRAPHING f(x) for different μ values 



μ_vals = [-1.5, -1.0, -0.5, 0.0, 0.5]

μ_vals = [-0.5]

# for μ ∈ μ_vals

#     fig = phase_line(x -> f(x,μ), a = -5.0, b = 5.0, df_tol = df_tol, f_tol = f_tol, Δx = Δx, npoints = 200, ymin = -2.0, ymax = 2.0,
#                 title = "Phase Line", xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)
# end

μ = -0.5

fig = phase_line(x -> f(x,μ), a = -5.0, b = 5.0, df_tol = df_tol, f_tol = f_tol, Δx = Δx, npoints = 200, ymin = -2.0, ymax = 2.0,
                title = "Phase Line", xlabel = L"x", ylabel = L"\dot{x}", figscale = 1.0)

# %%
phase_portraits = []

#for μ ∈ [-1.0]

for μ ∈ μ_vals
    pp = plot_phase_portrait(μ = μ, ntraj = 8, t0 = 0.0, tf = 3.0)
    push!(phase_portraits, pp)

    filename = "S24_Q1_phase_portrait_mu=$μ.png"
    save(filename, pp)
    
end
